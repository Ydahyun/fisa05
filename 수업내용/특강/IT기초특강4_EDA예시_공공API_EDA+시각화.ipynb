# %% [markdown]
# # Open API
# - 데이터를 공유하기 위한 목적으로 제공되는 서비스
#   - 요청 URL을 이용해서 서비스를 구분
#   - 즉, 데이터를 공유받기 위해서는 해당 서비스의 URL을 알면 됩니다,
#   - 그 URL을 API라고 합니다.
#
# - Open API의 사용방법
#   - 대부분이 API 사용신청을 해야되고
#     - 키값을 받아와서 요청할 때 키값을 설정을 알려줘야 사용 가능합니다.
#     - 회사마다 다르기 때문에 API 사용 설명서를 제공
#
# https://www.data.go.kr/data/15012005/openapi.do?recommendDataYn=Y
#
# https://github.com/WooilJeong/PublicDataReader
#
# # 소상공인시장진흥공단_상가(상권)정보
# https://www.data.go.kr/data/15083033/fileData.do
#
# 전체 파일을 가지고 와서 서울시 파일만 불러옵니다.

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 46.1 MB/s eta 0:00:00
# ...

# %%
import warnings
warnings.filterwarnings('always') # warning
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns

np.set_printoptions(precision=6, suppress=True)
pd.options.display.float_format = '{:.2f}'.format

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_gg = '/content/소상공인시장진흥공단_상가(상권)정보_경기_202503.csv'
path_s  = '/content/소상공인시장진흥공단_상가(상권)정보_서울_202503.csv'
path_in = '/content/소상공인시장진흥공단_상가(상권)정보_인천_202503.csv'

# %%
kyounggi = pd.read_csv(path_gg)
kyounggi.head(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-5-4056682306.py in <cell line: 0>()
# ----> 1 kyounggi = pd.read_csv(path_gg)
#       2 kyounggi.head(1)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # 1100, 780, 783, 779

# %% [markdown]
# CSV 파일의 구분자는 콤마 이외에 다른 문자를 사용할 수도 있습니다.

# %%
seoul= pd.read_csv(path_s)
seoul.head(1)
# Out:
#                  상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  MA010120220800000033  부동산임대김은숙  NaN        I2       음식      I212    비알코올
#
#   상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 0    I21201       카페   I56229  ...  1111014000100280021026727  NaN
#
#                  도로명주소   구우편번호 신우편번호  동정보  층정보  호정보     경도    위도
# 0  서울특별시 종로구 삼청로 122-1  110230  3053  NaN  NaN  NaN 126.98 37.59
#
# [1 rows x 39 columns]

# %%
incheon = pd.read_csv(path_in)
incheon.head(1)
# Out:
#                  상가업소번호 상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0  MA010120220800000474  실버  NaN        I1       숙박      I101    일반 숙박
#
#   상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 0    I10102    여관/모텔   I55102  ...  2817010600102710070187009  NaN
#
#                     도로명주소     구우편번호  신우편번호  동정보  층정보  호정보     경도    위도
# 0  인천광역시 미추홀구 석바위로114번길 9 402839.00  22140  NaN  NaN  NaN 126.69 37.46
#
# [1 rows x 39 columns]

# %%
seoul.describe(include='all').T
# Out:
#               count  unique                        top    freq  \
# 상가업소번호       540517  540517       MA0101202502A0114234       1
# 상호명          540517  428706                      컴퓨터수리     441
# 지점명           48544     860                        코리아    5890
# 상권업종대분류코드    540517      10                         I2  139929
# 상권업종대분류명     540517      10                         음식  139929
# 상권업종중분류코드    540517      75                       I201   49988
# 상권업종중분류명     540517      75                         한식   49988
# 상권업종소분류코드    540517     247                     L10203   25000
# 상권업종소분류명     540517     247                 부동산 중개/대리업   25000
# 표준산업분류코드     540317     371                     I56111   36885
# 표준산업분류명      540317     371                 한식 일반 음식점업   36885
# 시도코드      540517.00     NaN                        NaN     NaN
# 시도명          540517       1                      서울특별시  540517
# 시군구코드     540517.00     NaN                        NaN     NaN
# ...

# %%
# 데이터가 많아지면 데이터를 파악하기도 힘들어집니다.
# 작은 거 -> 전체에 적용 (seoul) 하나만 살펴보고 -> (sudogwon)
# 필요한 컬럼만 사본 만들기
# 결측치 확인하기

# %%
seoul.head(1).T
# Out:
#                                    0
# 상가업소번호          MA010120220800000033
# 상호명                         부동산임대김은숙
# 지점명                              NaN
# 상권업종대분류코드                         I2
# 상권업종대분류명                          음식
# 상권업종중분류코드                       I212
# 상권업종중분류명                       비알코올
# 상권업종소분류코드                     I21201
# 상권업종소분류명                          카페
# 표준산업분류코드                      I56229
# 표준산업분류명                 기타 비알코올 음료점업
# 시도코드                              11
# 시도명                            서울특별시
# 시군구코드                          11110
# 시군구명                             종로구
# 행정동코드                       11110540
# 행정동명                             삼청동
# 법정동코드                     1111014000
# 법정동명                             삼청동
# 지번코드             1111014000100280021
# 대지구분코드                             1
# 대지구분명                             대지
# 지번본번지                          28.00
# 지번부번지                          21.00
# ...

# %% [markdown]
# # 데이터 탐색

# %% [markdown]
# CSV 파일의 구분자는 콤마 이외에 다른 문자를 사용할 수도 있습니다.

# %%
seoul.지점명.isnull().sum() # 결측값의 개수
# Out:
# np.int64(491973)

# %%
# seoul 이라는 데이터프레임에 다운받은 파일 저장하기

# %%
import missingno as msno
# 결측데이터들을 파악하는데 직관적인 도움을 주는 패키지
msno.matrix(seoul)
# 데이터가 아주 많다면 굳이 결측치나 이상치를 채우지 않고 드랍합니다.
# 행 또는 열로 데이터의 80% 이상 차있으면 결측치를 채워넣습니다. -> mean, median, mode
# Out:
# <Axes: >

# %%
# 이 정보를 얻기 위해 간직해야할 컬럼 빼고 나머지는 다 버린 후에 아래 빈 문항들을 채워보세요.
# 서울시에 구별로 가장 많은 '카페' 체인점은 무엇인가?

# %%
seoul = seoul.drop(['지점명', '건물부번지', '동정보', '호정보'], axis=1)

# %%
seoul.상권업종중분류명.unique()
# Out:
# array(['비알코올 ', '부동산 서비스', '한식', '시계·귀금속 소매', '섬유·의복·신발 소매', '식료품 소매',
#        '기타 생활용품 소매', '이용·미용', '기타 가정용품 수리', '인쇄·제품제작', '의약·화장품 소매', '세탁',
#        '유원지·오락', '가전·통신 소매', '장식품 소매', '기타 간이', '주점', '종합 소매',
#        '기타 사업 서비스', '가전제품 수리', '전문 디자인', '청소·방제', '기술 서비스', '안경·정밀기기 소매',
#        '광고', '서양식', '사진 촬영', '자동차 수리·세차', '중식', '컴퓨터 수리', '기타 전문 과학',
#        '오락용품 소매', '산업용품 대여', '기타 상품 소매', '여행사·보조', '중고 상품 소매', '스포츠 서비스',
#        '기타 교육', '회계·세무', '법무관련 ', '담배 소매', '본사·경영 컨설팅', '교육 지원',
#        '철물·건설자재 소매', '일식', '사무 지원', '통신장비 수리', '가정용품 대여', '음료 소매',
#        '고용 알선', '모터사이클 소매', '기타 숙박', '일반 숙박', '욕탕·신체관리', '동남아시아',
#        '구내식당·뷔페', '애완동물·용품 소매', '시설관리', '기타 보건', '수의', '식물 소매', '기타 개인',
#        '연료 소매', '도서관·사적지', '일반 교육', '운송장비 대여', '가구 소매', '모터사이클 수리', '의원',
#        '병원', '자동차 부품 소매', '시장 조사', '장례식장 ', '조경·유지', '기타 외국'],
#       dtype=object)

# %%
seoul.상권업종중분류명.isin(['카페']).sum() # 완전일치
# Out:
# np.int64(0)

# %%
seoul.상권업종소분류명.isin(['카페']).sum() # 행의 개수(총합)
# Out:
# np.int64(22945)

# %%
seoul.상권업종소분류명.str.contains('카페').sum() # 일부 일치
# Out:
# np.int64(25480)

# %%
seoul.상권업종소분류명[seoul.상권업종소분류명.str.contains('카페')].unique()
# Out:
# array(['카페', '독서실/스터디 카페'], dtype=object)

# %%
seoul_coffee = seoul[seoul.상권업종소분류명.isin(['카페'])]

# %%
seoul_coffee
# Out:
#                       상가업소번호            상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220800000033       부동산임대김은숙        I2       음식      I212
# 29      MA010120220800000302             한옥        I2       음식      I212
# 66      MA010120220800001558           화동커피        I2       음식      I212
# 73      MA010120220800001379       우궁옛날전통찻집        I2       음식      I212
# 97      MA010120220800000971             상록        I2       음식      I212
# ...                      ...            ...       ...      ...       ...
# 540449  MA0106202201A0056383            이디야        I2       음식      I212
# 540460  MA0106202201A0056990           커피트립        I2       음식      I212
# 540482  MA0101202502A0103021  메가엠지씨커피쌍문세라믹점        I2       음식      I212
# 540495  MA0101202502A0109064   투썸플레이스신정뉴타운점        I2       음식      I212
# 540501  MA0101202502A0110204            소르르        I2       음식      I212
#
#        상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드       표준산업분류명  ...  \
# ...

# %% [markdown]
# - 해당 데이터에서 서울시내 이디야 매장 정보만 추출해보기

# %%
# Out:
# Series([], Name: 상호명, dtype: object)

# %%
idiya = seoul_coffee[seoul_coffee.상호명.str.contains('이디야')] # 일부일치
idiya.상호명.unique()
# Out:
# array(['이디야커피', '이디야다동점', '이디야연남동점', '이디야한국', '이디야회현SK리더스점', '이디야퇴계로2길점',
#        '이디야홈플러스', '이디야커피합정LIG점', '이디야화곡로점', '이디야', '이디야라이프점', '이디야커피영등포',
#        '이디야주', '이디야커피해군회관점', '이디야커피삼성', '이디야커피노량진CTS점', '이디야응암',
#        '이디야중곡대원점', '이디야커피천호초교', '이디야커피여의도역점', '이디야커피신도림테크노마트점', '이디야커피성동',
#        '이디야커피내방역점', '이디야커피보라매공원점', '이디야커피신림패션', '이디야커피구로거리공원점',
#        '이디야에스프레소', '이디야목3동점', '이디야신림', '이디야커피사가정', '이디야커피한티역점',
#        '이디야영등포그랜드점', '이디야커피목동신목점', '이디야혜화역점', '이디야불광', '이디야커피도림점',
#        '이디야커피신길역점', '이디야서소문점', '이디야장안중랑천점', '이디야커피강서한강자이', '이디야망원',
#        '이디야커피공릉역점', '이디야합정역', '이디야합정동점', '이디야커피아이온스퀘어', '이디야종로',
#        '이디야안암래미안점', '이디야커피신림대', '이디야을지로', '이디야커피명동역점', '이디야중곡',
#        '이디야커피선덕고', '이디야커피답십리', '이디야월계인덕점', '이디야커피배봉초교', '이디야장안동',
#        '이디야사가정점', '이디야커피회기', '이디야시립대점', '이디야마장역점', '이디야커피점신금호역점', '이디야성수',
#        '이디야커피촬영소', '이디야남구로역점', '이디야동덕여대점', '이디야카페정릉아리랑점', '이디야월곡동아점',
#        '이디야커피길동역점', '이디야거여역점', '이디야올림픽공원점', '이디야양재언남점', '이디야대림역점',
# ...

# %% [markdown]
# 서울시에 있는 카페 정보만 찾아 coffee라는 데이터프레임에 저장해보세요

# %% [markdown]
# 2025년 3월 31일 기준 서울시의 전체 카페 수는?

# %%
len(seoul_coffee)
# Out:
# 22945

# %% [markdown]
# 전체 coffee 상호 중 서울에 체인점이 많은 10개를 찾아보세요.

# %%
seoul_coffee.상호명.value_counts().iloc[99]
# Out:
# np.int64(5)

# %%
seoul_coffee.상호명.value_counts()
# Out:
# 상호명
# 투썸플레이스         75
# 이디야            66
# 이디야커피          65
# 메가엠지씨커피        63
# 컴포즈커피          49
#                ..
# 보통의             1
# 노이에아트멍          1
# 하우양재역점          1
# 광화문살롱           1
# 커피에반하다돌곶이역점     1
# Name: count, Length: 20039, dtype: int64

# %%
# 100개 150개를 먼저 떠서 거기서 replace 로 중복되는 값을 대체하거나, contains 일부일치를 탐색
coffee_shop = seoul_coffee.상호명.value_counts().index[:100]

# %%
# 커피라는 도메인에 관련된 데이터를 다룰 때는 '커피'를 빼면 오히려 분석하기 쉬워집니다.
# 중복 제거,
coffee_shop_set = set(map(lambda x: x.replace('커피', ''), coffee_shop))

# %%
seoul_coffee.상호명.str.contains('이디야').sum()
# Out:
# np.int64(488)

# %%
coffee_shop_set
# Out:
# {'',
#  '24시무인셀프카페',
#  '24시무인카페만월경',
#  '감성',
#  '고망고',
#  '공간',
#  '공차',
#  '과일에반하다프루타',
#  '국민우유집',
#  '기업',
#  '나무',
#  '나우',
#  '나이스카페인클럽',
#  '놀숲',
#  '니',
#  '달리는',
#  '더리터',
#  '더벤티',
#  '더빈마켓',
#  '더치앤빈',
#  '더카페',
#  '디저트39',
#  '마린',
#  '마마',
#  '마마퀸',
#  '만랩',
#  '매머드익스프레스',
#  '메가',
#  '메가엠지씨',
#  '메가후르츠',
#  '바나타이거',
#  '바나프레소',
#  '백억',
#  '벌툰',
#  '베이',
#  '벤티프레소',
#  '봉명동내',
#  '브루클린',
#  '블루샥',
#  '빽다방',
#  '설빙',
#  '스트렝스',
#  '아리스타',
#  '아마스빈',
#  '아우프글렛',
#  '에그카페24',
#  '에반하다',
#  '에슬로우',
#  '오아시스',
#  '오페라빈',
#  '온리',
#  '요거트퍼플',
#  '요거프레소',
#  '요커',
#  '우지',
#  '유캔두잇',
#  '읍천리382',
#  '이공',
#  '이디야',
#  '인류',
#  '일',
#  '좋은날',
#  '쥬씨',
#  '집',
#  '카페',
#  '카페게이트',
#  '카페미뇽',
#  '카페아이엠티',
#  '카페오늘',
#  '카페요아정',
#  '카페인',
#  '카페인중독',
#  '카페일리터',
#  '카페일분',
#  '카페홈즈',
#  '커스텀',
#  '컴포즈',
#  '컴포즈송파',
#  '타래퀸',
#  '탐앤탐스',
#  '테이큰',
#  '텐퍼센트',
#  '토프레소',
#  '투썸플레이스',
#  '파란만잔',
#  '파스쿠찌',
#  '팔공티',
#  '펠어초코',
#  '포트캔',
#  '폴바셋',
#  '퐁치익스프레스',
#  '플래시',
#  '플러스82',
# ...

# %%
result = {} # {상호명:포함되는개수 }

for coffe_shop in coffee_shop_set:
    count = seoul_coffee.상호명.str.contains(coffe_shop).sum()
    result[coffe_shop] = count

# %%
sorted(result.items(), key=lambda x: x[1], reverse=True)

# '메가', np.int64(855)
# Out:
# [('', np.int64(22945)),
#  ('카페', np.int64(3283)),
#  ('메가', np.int64(855)),
#  ('메가엠지씨', np.int64(782)),
#  ('니', np.int64(523)),
#  ('이디야', np.int64(488)),
#  ('일', np.int64(473)),
#  ('컴포즈', np.int64(451)),
#  ('매머드익스프레스', np.int64(383)),
#  ('빽다방', np.int64(368)),
#  ('투썸플레이스', np.int64(288)),
#  ('베이', np.int64(211)),
#  ('하우', np.int64(208)),
#  ('집', np.int64(170)),
#  ('더벤티', np.int64(165)),
#  ('공차', np.int64(149)),
#  ('할리스', np.int64(127)),
#  ('에반하다', np.int64(113)),
#  ('카페인', np.int64(93)),
#  ('나무', np.int64(92)),
#  ('탐앤탐스', np.int64(71)),
#  ('바나프레소', np.int64(66)),
#  ('디저트39', np.int64(65)),
#  ('텐퍼센트', np.int64(64)),
#  ('백억', np.int64(61)),
#  ('설빙', np.int64(58)),
#  ('파스쿠찌', np.int64(57)),
#  ('더카페', np.int64(54)),
#  ('쥬씨', np.int64(53)),
#  ('아마스빈', np.int64(48)),
#  ('폴바셋', np.int64(48)),
#  ('우지', np.int64(47)),
#  ('공간', np.int64(43)),
#  ('카페게이트', np.int64(38)),
#  ('포트캔', np.int64(36)),
#  ('달리는', np.int64(35)),
#  ('요거프레소', np.int64(35)),
# ...

# %% [markdown]
# 프랜차이즈 기준 가장 많은 커피 전문점은?

# %%
# '메가', np.int64(855)

# %%
seoul_coffee.상호명[seoul_coffee.상호명.str.contains('메가')].unique()
# Out:
# array(['메가엠지씨커피논현아크로힐스점', '메가엠지씨커피천왕이펜하우스점', '메가엠지씨커피신월', '식빵은여기메가커피',
#        '메가커피우', '메가엠지씨커피미아', '메가엠지씨커피미아현대점', '메가엠지씨커피군자역점', '메가엠지씨쌍문세라믹점',
#        '메가엠지씨커피시흥', '메가엠지씨커피방학도깨비시장', '메가엠지씨커피', '투썸플레이스목동메가박스',
#        '메가엠지씨커피면목', '메가커피', '메가엠지씨커피강북북부', '메가엠지씨커피중계씨앤미점', '메가커피문정',
#        '메가엠지씨커피면목면동초점', '메가엠지씨커피용마산역점', '메가엠지씨커피영등포전화국', '메가엠지씨커피오류동역점',
#        '메가커피현대', '메가엠지씨커피노원포레나점', '메가엠지씨커피우', '메가엠지씨커피한티역점', '메가엠지씨커피종암',
#        '메가엠지씨커피올림픽공원북문점', '메가엠지씨커피개봉', '메가엠지씨커피한남', '메가커피신곡', '메가폰엔터테인먼트',
#        '메가엠지씨커피신용산역점', '메가엠지씨커피거여역점', '메가엠지씨커피마포성산점', '메가엠지씨커피봉일',
#        '메가엠지씨커피강동역점', '메가엠지씨커피응암', '메가엠지씨커피마포시민공원점', '메가엠지씨커피동부',
#        '메가엠지씨커피대흥역점', '메가엠지씨커피가산SKV1', '메가커피신도림역점', '메가엠지씨커피창동역점',
#        '메가엠지씨커피창동', '메가엠지씨커피은행', '메가커피지하도점', '메가엠지씨커피염창역점',
#        '메가엠지씨커피양평중흥S클래스점', '파스쿠찌교대메가스터디점', '메가엠지씨커피잠실나루역점',
#        '메가엠지씨커피서울공덕초교점', '메가엠지씨커피명동중앙우체국점', '메가엠지씨커피신림역', '메가엠지씨커피논골',
#        '메가엠지씨커피대치역점', '메가엠지씨커피신월5동점', '메가엠지씨커피구산역점', '메가커피잠실레이크',
# ...

# %%
seoul_coffee.상호명[seoul_coffee.상호명.str.contains('메가스터디')].unique()
# Out:
# array(['파스쿠찌교대메가스터디점', '매머드익스프레스메가스터디'], dtype=object)

# %%
first_coffee = seoul_coffee[~seoul_coffee.상호명.str.contains('메가스터디') & seoul_coffee.상호명.str.contains('메가')]

# %%
# 853개, 메가커피

# %% [markdown]
# 카페 이름이 `상호명`으로만 들어있지 않다는 경우도 있다는거 아세요?

# %% [markdown]
# 1위 브랜드의 매장 정보만 추출해 coffee_first 라는 데이터프레임에 저장해보세요

# %%
first_coffee.시군구명.unique()
# Out:
# array(['강남구', '구로구', '양천구', '송파구', '강서구', '강북구', '성북구', '광진구', '도봉구',
#        '금천구', '중랑구', '노원구', '영등포구', '관악구', '강동구', '용산구', '마포구', '은평구',
#        '동대문구', '중구', '성동구', '서대문구', '서초구', '동작구', '종로구'], dtype=object)

# %%
구별매장수 = first_coffee.groupby('시군구명')[['상가업소번호']].count().sort_values(by='상가업소번호',ascending=False)

# %%
구별매장수
# Out:
#       상가업소번호
# 시군구명
# 강남구       61
# 송파구       56
# 강서구       47
# 영등포구      46
# 마포구       44
# 노원구       42
# 서초구       38
# 구로구       37
# 성북구       37
# 양천구       37
# 은평구       34
# 중구        34
# 동대문구      32
# 강동구       32
# 관악구       32
# 중랑구       29
# 종로구       29
# 서대문구      28
# 도봉구       26
# 강북구       26
# 광진구       25
# 금천구       25
# 성동구       21
# 동작구       20
# 용산구       15

# %%
first_coffee.groupby('시군구명')[['상가업소번호']].count().sort_values(by='상가업소번호',ascending=False).sum()
# Out:
# 상가업소번호    853
# dtype: int64

# %%
first_coffee.head(1)
# Out:
#                     상가업소번호              상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 5212  MA010120220800062311  메가엠지씨커피논현아크로힐스점        I2       음식      I212
#
#      상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드 표준산업분류명  ...            도로명  건물본번지  \
# 5212    비알코올     I21201       카페   I56221  커피 전문점  ...  서울특별시 강남구 언주로 604.00
#
#                          건물관리번호      건물명              도로명주소   구우편번호  신우편번호  \
# 5212  1168010800102760000026382  아크로힐스논현  서울특별시 강남구 언주로 604  135833   6102
#
#      층정보     경도    위도
# 5212   1 127.04 37.51
#
# [1 rows x 35 columns]

# %%
len(first_coffee) # 합, null의 개수, 행의 개수
# Out:
# 853

# %% [markdown]
# 서울시에서 가장 많은 이 브랜드의 매장이 위치한 구는 어디일까요? x축을 '시군구명', y축을 해당 브랜드 매장의 개수로 하는 바그래프를 그려보세요.

# %%
구별매장수.index
# Out:
# Index(['강남구', '송파구', '강서구', '영등포구', '마포구', '노원구', '서초구', '구로구', '성북구', '양천구',
#        '은평구', '중구', '동대문구', '강동구', '관악구', '중랑구', '종로구', '서대문구', '도봉구', '강북구',
#        '광진구', '금천구', '성동구', '동작구', '용산구'],
#       dtype='object', name='시군구명')

# %%
구별매장수
# Out:
#       상가업소번호
# 시군구명
# 강남구       61
# 송파구       56
# 강서구       47
# 영등포구      46
# 마포구       44
# 노원구       42
# 서초구       38
# 구로구       37
# 성북구       37
# 양천구       37
# 은평구       34
# 중구        34
# 동대문구      32
# 강동구       32
# 관악구       32
# 중랑구       29
# 종로구       29
# 서대문구      28
# 도봉구       26
# 강북구       26
# 광진구       25
# 금천구       25
# 성동구       21
# 동작구       20
# 용산구       15

# %%
import plotly.express as px

px.bar(구별매장수, x=구별매장수.index,  y='상가업소번호')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 위에서 만든 seoul, incheon, kyounggi 를 모두 합한 데이터프레임으로 수도권(sudogwon)에 가장 매장이 많은 커피전문점의 이름과, 개수를 찾아주세요.

# %%
sudogwon = pd.concat([seoul, incheon, kyounggi], ignore_index=True)

# %%
len(set(seoul.columns))
# Out:
# 39

# %%
len(set(seoul.columns) & set(incheon.columns) & set(kyounggi.columns))
# Out:
# 39

# %%
kyounggi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 654283 entries, 0 to 654282
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     654283 non-null  object
#  1   상호명        654283 non-null  object
#  2   지점명        64480 non-null   object
#  3   상권업종대분류코드  654283 non-null  object
#  4   상권업종대분류명   654283 non-null  object
#  5   상권업종중분류코드  654283 non-null  object
#  6   상권업종중분류명   654283 non-null  object
#  7   상권업종소분류코드  654283 non-null  object
#  8   상권업종소분류명   654283 non-null  object
#  9   표준산업분류코드   654054 non-null  object
#  10  표준산업분류명    654054 non-null  object
#  11  시도코드       654283 non-null  int64
#  12  시도명        654283 non-null  object
#  13  시군구코드      654283 non-null  int64
#  14  시군구명       654283 non-null  object
#  15  행정동코드      654283 non-null  int64
#  16  행정동명       654283 non-null  object
#  17  법정동코드      654283 non-null  int64
#  18  법정동명       654283 non-null  object
# ...

# %%
(set(seoul.columns) & set(incheon.columns) & set(kyounggi.columns))
# Out:
# {'건물관리번호',
#  '건물명',
#  '건물본번지',
#  '건물부번지',
#  '경도',
#  '구우편번호',
#  '대지구분명',
#  '대지구분코드',
#  '도로명',
#  '도로명주소',
#  '도로명코드',
#  '동정보',
#  '법정동명',
#  '법정동코드',
#  '상가업소번호',
#  '상권업종대분류명',
#  '상권업종대분류코드',
#  '상권업종소분류명',
#  '상권업종소분류코드',
#  '상권업종중분류명',
#  '상권업종중분류코드',
#  '상호명',
#  '시군구명',
#  '시군구코드',
#  '시도명',
#  '시도코드',
#  '신우편번호',
#  '위도',
#  '지번본번지',
#  '지번부번지',
#  '지번주소',
#  '지번코드',
#  '지점명',
#  '층정보',
#  '표준산업분류명',
#  '표준산업분류코드',
#  '행정동명',
#  '행정동코드',
#  '호정보'}

# %%
len(seoul)+len(incheon)+len(kyounggi)
# Out:
# 1328668

# %%
len(pd.concat([seoul, incheon, kyounggi]))
# Out:
# 1328668

# %% [markdown]
# 커피라는 도메인과 관련해서 이 데이터에서 더 얻어낼 인사이트는 없을까요?
# - 참고: https://myfranchise.kr/category/contents/%EC%B9%B4%ED%8E%98%C2%B7%EB%94%94%EC%A0%80%ED%8A%B8/%EC%BB%A4%ED%94%BC

# %%
sudogwon_cafe = sudogwon[sudogwon.상권업종소분류명 == '카페'] # 완전 일치

# %%
len(sudogwon_cafe)
# Out:
# 56014

# %%
sudogwon_cafe.상호명.value_counts().sort_values(ascending=False)
# Out:
# 상호명
# 투썸플레이스         144
# 이디야커피          137
# 커피에반하다         132
# 메가엠지씨커피        126
# 이디야            121
#               ...
# 존맛빙수             1
# 카페유일             1
# 컴포즈커피성남수정로점      1
# 카페밍고일산후곡         1
# 카페마방             1
# Name: count, Length: 46162, dtype: int64

# %%
sudogwon_coffee = sudogwon_cafe.상호명.value_counts().sort_values(ascending=False).index[:100]

# %%
set(map(lambda x: x.replace('커피', ''), sudogwon_coffee))
# Out:
# {'',
#  '24시무인셀프카페',
#  '24시무인카페만월경',
#  '감성',
#  '고망고',
#  '공간',
#  '공차',
#  '과일에반하다프루타',
#  '금다방',
#  '나무',
#  '나우',
#  '날쌘카페',
#  '놀숲',
#  '니',
#  '달리는',
#  '더리터',
#  '더벤티',
#  '더치앤빈',
#  '더카페',
#  '데이롱카페',
#  '동네',
#  '디저트39',
#  '랑데자뷰',
#  '마마',
#  '마마퀸',
#  '만랩',
#  '매머드익스프레스',
#  '메가',
#  '메가엠지씨',
#  '메가엠지씨수원',
#  '메가엠지씨인천',
#  '바나프레소',
#  '반달',
#  '발도스',
#  '백억',
#  '벌툰',
#  '베이',
#  '별다방',
#  '복다방',
#  '봉명동내',
#  '비주거용 건물 임대업',
#  '빙동댕',
#  '빽다방',
#  '설빙',
#  '셀렉토',
#  '소풍',
#  '수다방',
#  '스토리',
#  '아마스빈',
#  '약속다방',
#  '에그카페24',
#  '에반하다',
#  '오늘',
#  '요거트퍼플',
#  '요거프레소',
#  '요커',
#  '우주라이크',
#  '우지',
#  '읍천리382',
#  '이디야',
#  '이야기',
#  '정다방',
#  '중앙다방',
#  '쥬씨',
#  '집',
#  '카페',
#  '카페게이트',
#  '카페동네',
#  '카페봄봄',
#  '카페오늘',
#  '카페온',
#  '카페요아정',
#  '카페인',
#  '카페인중독',
#  '카페일리터',
#  '카페일분',
#  '카페테라스',
#  '카페하루',
#  '카페홈즈',
#  '커스텀',
#  '컴포즈',
#  '컴포즈수원',
#  '콩',
#  '타래퀸',
#  '타임',
#  '탐앤탐스',
#  '텐퍼센트',
#  '토프레소',
#  '투썸플레이스',
#  '트리플에이',
#  '파스쿠찌',
#  '팔공티',
#  '포트캔',
# ...

# %%
len(sudogwon[sudogwon.상호명 == '메가엠지씨커피인천'])

# %%
sudogwon[sudogwon.상호명.str.contains('메가엠지씨커피인천')]
# Out:
#                       상가업소번호             상호명   지점명 상권업종대분류코드 상권업종대분류명  \
# 541399  MA010120220800299823     메가엠지씨커피인천검단  사거리점        I2       음식
# 541701  MA010120220800459158   메가엠지씨커피인천논현역점   NaN        I2       음식
# 571558  MA010120220802905724     메가엠지씨커피인천함박   마을점        I2       음식
# 571740  MA010120220802917122     메가엠지씨커피인천효성   남초점        I2       음식
# 572225  MA010120220803002351       메가엠지씨커피인천   효성점        I2       음식
# ...                      ...             ...   ...       ...      ...
# 670681  MA0101202501A0055379   메가엠지씨커피인천예술고점   NaN        I2       음식
# 670828  MA0101202412A0069816     메가엠지씨커피인천동춘   대림점        I2       음식
# 670890  MA0101202412A0058976   메가엠지씨커피인천국세청점   NaN        I2       음식
# 671849  MA0101202412A0010501     메가엠지씨커피인천삼산   광명점        I2       음식
# 673963  MA0101202502A0100314  메가엠지씨커피인천만수5동점   NaN        I2       음식
#
#        상권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...  \
# 541399      I212    비알코올     I21201       카페   I56221  ...
# ...

# %%
import json

# 서울시군구
seoulsigungu = json.load(open('/content/drive/MyDrive/WOORIFISA 5기 AI엔지니어링/data/seoulsigungu.geojson'))
seoulsigungu['features'][0]['properties']['SIG_KOR_NM'] # 국제표준
# Out:
# '도봉구'

# %%
type(seoulsigungu)
# Out:
# dict

# %%
type(seoulsigungu['features'][0])
# Out:
# dict

# %%
seoulsigungu['features'][0]['properties']
# Out:
# {'SIG_CD': '11320',
#  'SIG_KOR_NM': '도봉구',
#  'SIG_ENG_NM': 'Dobong-gu',
#  'ESRI_PK': 0,
#  'SHAPE_AREA': 0.00210990544544,
#  'SHAPE_LEN': 0.239901251347}

# %%
seoulsigungu['features'][0]['geometry']
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[127.019851357, 37.70088490199998],
#    [127.02217147700003, 37.69960736799999],
#    [127.02341184299996, 37.69995983299998],
#    [127.02533791899998, 37.69948105499998],
#    [127.02692041600005, 37.70015310500003],
#    [127.02704481599994, 37.70101150699998],
#    [127.02771004600004, 37.70083744700003],
#    [127.02823835, 37.700188083],
#    [127.02833534499996, 37.70006885100003],
#    [127.02901307699995, 37.69957318899998],
#    [127.02930740500005, 37.699210467],
#    [127.02962280199995, 37.69810365199999],
#    [127.02967567200005, 37.69773805400001],
#    [127.02975002699998, 37.69621560600001],
#    [127.03018658500002, 37.69515116600002],
#    [127.03047411600005, 37.69473308800002],
#    [127.03052254600004, 37.69459605999998],
#    [127.030703367, 37.69408591299998],
#    [127.03075779200003, 37.69390196900002],
#    [127.03084669999998, 37.69365666800002],
#    [127.03099203199997, 37.69352532200003],
# ...

# %%
first_coffee.위도.mean()
# Out:
# np.float64(37.549517225181184)

# %%
import plotly.express as px

# 매장수2에 있는 시군구명을 기준으로 seoulsigungu의 SIG_KOR_NM이 일치하면 그 자리에 상호명에 들어있는 숫자를 색깔로 표현
fig = px.choropleth_map(first_coffee, geojson=seoulsigungu, locations='시군구명', color='상호명',
                           color_continuous_scale="Viridis",
                           map_style="carto-positron",
                           zoom=8, center = {"lat": first_coffee.위도.mean(), "lon":first_coffee.경도.mean()},
                            featureidkey='properties.SIG_KOR_NM'
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# # 이제 지도 위에 표시를 해 봅시다.

# %%
import folium

# %%
# 각 매장의 평균 경도와 위도를 기준으로 그려 봅시다.
lat = first_coffee['위도'].mean()
lng = first_coffee['경도'].mean()

# %%
map = folium.Map( location = [ lat, lng ], zoom_start=11 )

# 기본 마커를 이용해서 지도에 매장 위치를 찍어 봅니다.
# 마커를 생성해서 지도에 전부 추가

for i in first_coffee.index:
  folium.Marker( [ first_coffee.loc[i, '위도'], first_coffee.loc[i, '경도'] ]).add_to(map)

map

# %% [markdown]
# 표현해야 되는 자료가 매우 많으면 기본 마커로 전부 찍는건 불가능합니다. 그럴 땐 폴리움이 제공하는 다른 모듈을 이용합니다.

# %% [markdown]
# 단계구분도를 이용해 표현해보기
# - `시군구` 이름을 사용해서 행정구역별 매장 수를 표현

# %% [markdown]
# 시군구별 매장수를 구해 봅니다.

# %%
import json

# %%
map = folium.Map( location = [ lat, lng ], zoom_start=11 )

location = []
for i in first_coffee.index:
  location.append( [ first_coffee.loc[i, '위도'], first_coffee.loc[i, '경도'] ] )

MarkerCluster( location, overlay=True).add_to(map)

map

# %%
map = folium.Map( location = [ lat, lng ], zoom_start=11, tiles="CartoDB dark_matter" )

folium.Choropleth(
  geo_data = geojson,
  data = ??,
  columns = [??.index, '매장수'],
  fill_color='YlOrRd',
  # fill_opacity = 0.7,
  # line_opacity=0.5,
  key_on = 'properties.SIG_KOR_NM'
).add_to(map)

map
